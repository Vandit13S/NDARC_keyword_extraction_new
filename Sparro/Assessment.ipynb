# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler

# %%
file_name_1 = 'Data | C.1.csv'
df = pd.read_csv(file_name_1,skiprows=[0],header=0)

# %%
df.head()
# Out:
#                   Keyword Currency Segmentation  Avg. monthly searches  \
# 0                     NaN      NaN          All               231880.0
# 1                     NaN      NaN    Australia               231880.0
# 2         beach cover ups      AUD          NaN                 6600.0
# 3  black cocktail dresses      AUD          NaN                 6600.0
# 4  black designer dresses      AUD          NaN                  260.0
#
#   Three month change YoY change Competition  Competition (indexed value)  \
# 0                NaN        NaN         NaN                          NaN
# 1                NaN        NaN         NaN                          NaN
# 2               -19%         0%        High                         98.0
# 3                 0%         0%        High                        100.0
# 4               -19%       -19%        High                         97.0
#
#    Top of page bid (low range)  Top of page bid (high range)  ...  \
# 0                          NaN                           NaN  ...
# 1                          NaN                           NaN  ...
# 2                         0.35                          1.69  ...
# 3                         0.41                          1.39  ...
# 4                         0.60                          1.83  ...
#
#    Searches: Jul 2023  Searches: Aug 2023  Searches: Sep 2023  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2              6600.0              6600.0              8100.0
# 3              6600.0              8100.0              8100.0
# 4               320.0               210.0               260.0
#
#    Searches: Oct 2023  Searches: Nov 2023  Searches: Dec 2023  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2              8100.0              8100.0              9900.0
# 3              9900.0              8100.0              3600.0
# 4               480.0               210.0               140.0
#
#    Searches: Jan 2024  Searches: Feb 2024  Searches: Mar 2024  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2              9900.0              5400.0              5400.0
# 3              5400.0              5400.0              6600.0
# 4               260.0               320.0               260.0
#
#    Searches: Apr 2024
# 0                 NaN
# 1                 NaN
# 2              4400.0
# 3              5400.0
# 4               260.0
#
# [5 rows x 26 columns]

# %%
# Extracting All and Australia values
All = df.iloc[0, 3]
Australia = df.iloc[1, 3]
df = df.drop([0, 1]).reset_index(drop=True)
df.head()
# Out:
#                     Keyword Currency Segmentation  Avg. monthly searches  \
# 0           beach cover ups      AUD          NaN                 6600.0
# 1    black cocktail dresses      AUD          NaN                 6600.0
# 2    black designer dresses      AUD          NaN                  260.0
# 3  cocktail & formal styles      AUD          NaN                    NaN
# 4          cocktail dresses      AUD          NaN                74000.0
#
#   Three month change YoY change Competition  Competition (indexed value)  \
# 0               -19%         0%        High                         98.0
# 1                 0%         0%        High                        100.0
# 2               -19%       -19%        High                         97.0
# 3                NaN        NaN         NaN                          NaN
# 4                 0%        22%        High                        100.0
#
#    Top of page bid (low range)  Top of page bid (high range)  ...  \
# 0                         0.35                          1.69  ...
# 1                         0.41                          1.39  ...
# 2                         0.60                          1.83  ...
# 3                          NaN                           NaN  ...
# 4                         0.39                          1.36  ...
#
#    Searches: Jul 2023  Searches: Aug 2023  Searches: Sep 2023  \
# 0              6600.0              6600.0              8100.0
# 1              6600.0              8100.0              8100.0
# 2               320.0               210.0               260.0
# 3                 NaN                 NaN                 NaN
# 4             74000.0             90500.0             90500.0
#
#    Searches: Oct 2023  Searches: Nov 2023  Searches: Dec 2023  \
# 0              8100.0              8100.0              9900.0
# 1              9900.0              8100.0              3600.0
# 2               480.0               210.0               140.0
# 3                 NaN                 NaN                 NaN
# 4            110000.0            110000.0             49500.0
#
#    Searches: Jan 2024  Searches: Feb 2024  Searches: Mar 2024  \
# 0              9900.0              5400.0              5400.0
# 1              5400.0              5400.0              6600.0
# 2               260.0               320.0               260.0
# 3                 NaN                 NaN                 NaN
# 4             74000.0             74000.0             74000.0
#
#    Searches: Apr 2024
# 0              4400.0
# 1              5400.0
# 2               260.0
# 3                 NaN
# 4             74000.0
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Keyword                       67 non-null     object
#  1   Currency                      67 non-null     object
#  2   Segmentation                  0 non-null      object
#  3   Avg. monthly searches         59 non-null     float64
#  4   Three month change            59 non-null     object
#  5   YoY change                    59 non-null     object
#  6   Competition                   58 non-null     object
#  7   Competition (indexed value)   58 non-null     float64
#  8   Top of page bid (low range)   50 non-null     float64
#  9   Top of page bid (high range)  50 non-null     float64
#  10  Ad impression share           0 non-null      float64
#  11  Organic average position      0 non-null      float64
#  12  Organic impression share      0 non-null      float64
#  13  In Account                    0 non-null      float64
#  14  Searches: May 2023            59 non-null     float64
#  15  Searches: Jun 2023            59 non-null     float64
#  16  Searches: Jul 2023            59 non-null     float64
#  17  Searches: Aug 2023            59 non-null     float64
#  18  Searches: Sep 2023            59 non-null     float64
#  19  Searches: Oct 2023            59 non-null     float64
#  20  Searches: Nov 2023            59 non-null     float64
#  21  Searches: Dec 2023            59 non-null     float64
#  22  Searches: Jan 2024            59 non-null     float64
#  23  Searches: Feb 2024            59 non-null     float64
#  24  Searches: Mar 2024            59 non-null     float64
#  25  Searches: Apr 2024            59 non-null     float64
# dtypes: float64(20), object(6)
# memory usage: 13.7+ KB

# %%
#Since there are few columns which doesn't contain data at all, it is better to remove them
df = df.dropna(axis=1, how='all')

#Since only Search volume data is utilised in this task, we are dropping all the rows where any of the 
#monthly Search column is null
search_columns = [col for col in df.columns if col.startswith("Searches:")]
df.dropna(subset=search_columns, how='all', inplace=True)
df.reset_index(drop=True, inplace=True)

'''
For handling missing values of other columns, we can use following approaches.
For Top of page bid (low range) and Top of page bid (high range), depending on the field characteristic and 
the nature of anlysis, missing values for these numeric features can be filled with either mean, median or mode:
Although for this dataset, since each row represents a different keyword hence a different product, the search
volume for them can vary drastically, hence filling it with any central tendency is not recommended:
'''
#df['Top of page bid (low range)'] = df['Top of page bid (low range)'].fillna(df['Top of page bid (low range)'].mean())
#df['Top of page bid (high range)'] = df['Top of page bid (high range)'].fillna(df['Top of page bid (high range)'].mean())
'''
To fill missing values in Categorical field like Competition, majority or mode can be chosen, again depending on
the characteristics of field and analysis:
'''

#most_common_competition = df['Competition'].mode().iloc[0]
#df['Competition'] = df['Competition'].fillna(most_common_competition)
'''
Since Competition (indexed value) directly corresponds to Competition, we can create a mapping between them and use
some central tendency like median to fill the corresponding mising values:
'''
#competition_index_map = df.groupby('Competition')['Competition (indexed value)'].median().to_dict()

#def fill_competition_index(row):
#    if pd.isna(row['Competition (indexed value)']) and not pd.isna(row['Competition']):
#        return competition_index_map.get(row['Competition'], df['Competition (indexed value)'].median())
#    return row['Competition (indexed value)']

#df['Competition (indexed value)'] = df.apply(fill_competition_index, axis=1)
# Out:
# '\nSince Competition (indexed value) directly corresponds to Competition, we can create a mapping between them and use\nsome central tendency like median to fill the corresponding mising values:\n'

# %%
#Handling Three month change and YoY change by removing '%' and converting it to float
#Since there are many fields having '∞' symbol, it's worth to create a custom function for these conversions while 
#retaining infinity value which might be useful (can infer from domain knowledge)

def convert_to_float(value):
    if value == '∞':
        return np.inf
    elif value == '-∞':
        return -np.inf
    else:
        try:
            return float(value) / 100.0
        except ValueError:
            return np.nan

df['Three month change'] = df['Three month change'].str.rstrip('%')
df['YoY change'] = df['YoY change'].str.rstrip('%')

df['Three month change'] = df['Three month change'].apply(convert_to_float)
df['YoY change'] = df['YoY change'].apply(convert_to_float)

# %%
#For Keyword cleaning, there could be a lot NLP steps involved to handle many cases, like special characters in
#the keywords, standardizing variations (e.g. colour and color), and various other scenarios.

#For simplicity, doing just basic cleaning, i.e. converting it to lowercase for consistency and removing whitespace
df['Keyword'] = df['Keyword'].str.strip().str.lower()

# %%
#converting the column names to a standard format, lowercase, and removing special characters
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('.', '').str.replace('(', '').str.replace(')', '').str.replace(':', '')

# %% [markdown]
# ## The following chart shows average monthly searches over the given months for the company.
# #### Although the data is in product/keyword level granularity, this chart helps to understand the overall search trend for the company.

# %%
search_columns = [col for col in df.columns if col.startswith('searches_')]
df_searches = df[search_columns]
df_searches_mean = df_searches.mean()

new_labels = [col.split('_', 1)[1].capitalize().replace('_', ' ') for col in df_searches_mean.index]

plt.figure(figsize=(12, 6))
plt.plot(new_labels, df_searches_mean.values, marker='o')
plt.title('Average Monthly Searches Over Time')
plt.xlabel('Month')
plt.ylabel('Average Searches')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly search volume for each keyword

# %%
monthly_data = df[['keyword'] + search_columns]
monthly_data.columns = ['keyword'] + new_labels

# %%
monthly_data.head(len(monthly_data))
# Out:
#                                 keyword  May 2023  Jun 2023  Jul 2023  \
# 0                       beach cover ups    4400.0    5400.0    6600.0
# 1                black cocktail dresses    5400.0    5400.0    6600.0
# 2                black designer dresses     320.0     260.0     320.0
# 3                      cocktail dresses   60500.0   60500.0   74000.0
# 4                     cotton midi dress     320.0     480.0     590.0
# 5                           day dresses    1600.0    1600.0    1900.0
# 6                         denim dresses   22200.0   22200.0   33100.0
# 7                designer beach dresses      30.0      50.0      40.0
# 8   designer casual dresses for daywear       0.0       0.0       0.0
# 9             designer cocktail dresses     590.0     720.0     590.0
# 10                designer cotton dress      30.0      10.0      10.0
# 11                     designer dresses    4400.0    3600.0    4400.0
# 12                 designer eveningwear    1000.0     880.0    1000.0
# 13        designer floor length dresses      10.0      10.0       0.0
# 14              designer formal dresses     880.0     590.0     720.0
# 15             designer knitted dresses     210.0     170.0     170.0
# 16                 designer linen dress      50.0      70.0      90.0
# 17           designer long sleeve dress     720.0     480.0     480.0
# 18                designer midi dresses     390.0     320.0     480.0
# 19                designer mini dresses     390.0     390.0     480.0
# 20                 designer print dress      10.0      10.0      10.0
# 21                 designer resort wear      90.0     140.0      90.0
# 22           designer short denim dress       0.0       0.0       0.0
# 23          designer short sleeve dress      10.0       0.0      20.0
# 24                  designer silk dress      70.0      70.0     110.0
# 25            designer sleeveless dress       0.0       0.0       0.0
# 26              designer summer dresses     260.0     210.0     260.0
# 27                  designer wool dress      20.0      10.0       0.0
# 18     390.0     320.0
# 19     880.0     720.0
# 20      20.0      10.0
# 21     140.0     140.0
# 22      10.0      10.0
# 23      10.0      10.0
# 24     110.0      90.0
# 25      10.0      10.0
# 26     110.0     110.0
# 27      10.0      10.0
# 28   18100.0   18100.0
# 29    2400.0    2400.0
# 30     880.0     720.0
# 31     390.0     320.0
# 32    6600.0    6600.0
# 33     320.0     390.0
# 34    1600.0    3600.0
# 35    3600.0    1900.0
# 36    4400.0    9900.0
# 37    6600.0    9900.0
# 38    1000.0     720.0
# 39    4400.0    2900.0
# 40    1000.0    1300.0
# 41    1300.0     880.0
# 42    1600.0    1600.0
# 43     320.0     260.0
# 44      50.0      90.0
# 45     590.0     390.0
# 46   14800.0   14800.0
# 47     320.0     320.0
# 48      10.0       0.0
# 49    3600.0    2900.0
# 50     480.0     590.0
# 51    1600.0    1000.0
# 52     880.0     720.0
# 53     320.0     320.0
# 54     390.0     320.0
# 55     170.0      90.0
# 56    1000.0    1000.0
# 57     170.0     590.0
# 58      40.0      90.0

# %% [markdown]
# ### Month over Month biggest risers and fallers

# %%
#Working:
#Initially decided to show the biggest risers and fallers in terms of both Absolute and PCT change.
#Then faced the problem of inf value when previous month's search volume was 0, and tried handling it. 
#Finally realized that PCT change doesn't add much value compared to Absolute change, 
#for e.g. increase in search volume from 10 to 50 in PCT would be 400%, while 10k to 12k would be 20%, 
#but obviously the latter adds more value. 
#Following is the code with previous approach:

'''def mom_changes(df):
    search_columns = [col for col in df.columns if col.startswith('searches_')]
    monthly_data = df[['keyword'] + search_columns]
    
    for i in range(1, len(search_columns)):
        abs_change_col = f'mom_abs_change_{search_columns[i]}'
        pct_change_col = f'mom_pct_change_{search_columns[i]}'
        
        monthly_data[abs_change_col] = monthly_data[search_columns[i]] - monthly_data[search_columns[i-1]]
        monthly_data[pct_change_col] = (monthly_data[search_columns[i]] - monthly_data[search_columns[i-1]]) / monthly_data[search_columns[i-1]]
    
    abs_change_columns = [col for col in monthly_data.columns if col.startswith('mom_abs_change_')]
    
    for abs_col in abs_change_columns:
        month = abs_col.replace('mom_abs_change_searches_', '').replace('_', ' ').title()
        pct_col = abs_col.replace('abs', 'pct')
        
        # Absolute changes
        abs_riser = monthly_data.loc[monthly_data[abs_col].idxmax()]
        abs_faller = monthly_data.loc[monthly_data[abs_col].idxmin()]
        
        # Percentage changes
        pct_riser = monthly_data.loc[monthly_data[pct_col].idxmax()]
        pct_faller = monthly_data.loc[monthly_data[pct_col].idxmin()]
        
        print(f"\nFor {month}:")
        print("Absolute Changes:")
        print(f"Biggest Riser: {abs_riser['keyword']}: +{abs_riser[abs_col]:,.0f}")
        print(f"Biggest Faller: {abs_faller['keyword']}: {abs_faller[abs_col]:,.0f}")
        
        print("\nPercentage Changes:")
        print(f"Biggest Riser: {pct_riser['keyword']}: {pct_riser[pct_col]:+.2%}")
        print(f"Biggest Faller: {pct_faller['keyword']}: {pct_faller[pct_col]:.2%}")
        print("-"*60)
'''

def mom_changes(df):
    search_columns = [col for col in df.columns if col.startswith('searches_')]
    monthly_data = df[['keyword'] + search_columns]
    
    for i in range(1, len(search_columns)):
        change_col = f'mom_change_{search_columns[i]}'
        monthly_data[change_col] = monthly_data[search_columns[i]] - monthly_data[search_columns[i-1]]
    
    change_columns = [col for col in monthly_data.columns if col.startswith('mom_change_')]
    
    for col in change_columns:
        month = col.replace('mom_change_searches_', '').replace('_', ' ').title()
        biggest_riser = monthly_data.loc[monthly_data[col].idxmax()]
        biggest_faller = monthly_data.loc[monthly_data[col].idxmin()]
        
        print(f"\nFor {month}:")
        print(f"Biggest Riser: {biggest_riser['keyword']}: +{biggest_riser[col]:,.0f}")
        print(f"Biggest Faller: {biggest_faller['keyword']}: {biggest_faller[col]:,.0f}")
        print("-"*50)
        
mom_changes(df)
# Out:
# For Jun 2023:
# Biggest Riser: beach cover ups: +1,000
# Biggest Faller: long sleeve midi dress: -4,900
# --------------------------------------------------
#
# For Jul 2023:
# Biggest Riser: cocktail dresses: +13,500
# Biggest Faller: long sleeve knitted dress: -4,900
# --------------------------------------------------
#
# For Aug 2023:
# Biggest Riser: cocktail dresses: +16,500
# Biggest Faller: long sleeve knitted dress: -4,500
# --------------------------------------------------
#
# For Sep 2023:
# Biggest Riser: denim dresses: +9,000
# Biggest Faller: long sleeve knitted dress: -3,000
# --------------------------------------------------
#
# For Oct 2023:
# Biggest Riser: cocktail dresses: +19,500
# Biggest Faller: short sleeve knitted dress: -200
# --------------------------------------------------
#
# For Nov 2023:
# Biggest Riser: party dresses: +6,000
# Biggest Faller: evening dresses: -9,000
# --------------------------------------------------
#
# For Dec 2023:
# Biggest Riser: beach cover ups: +1,800
# Biggest Faller: cocktail dresses: -60,500
# --------------------------------------------------
#
# For Jan 2024:
# Biggest Riser: cocktail dresses: +24,500
# Biggest Faller: party dresses: -4,100
# --------------------------------------------------
#
# For Feb 2024:
# Biggest Riser: denim dresses: +9,000
# Biggest Faller: beach cover ups: -4,500
# --------------------------------------------------
#
# For Mar 2024:
# Biggest Riser: long sleeve midi dress: +3,000
# Biggest Faller: party dresses: -3,300
# --------------------------------------------------
#
# For Apr 2024:
# Biggest Riser: long sleeve knitted dress: +5,500
# Biggest Faller: denim dresses: -9,000
# --------------------------------------------------

# %%
def show_mom_changes(df, top_n=5):
    search_columns = [col for col in df.columns if col.startswith('searches_')]
    monthly_data = df[['keyword'] + search_columns]
    
    # Calculate month-over-month changes
    for i in range(1, len(search_columns)):
        change_col = f'mom_change_{search_columns[i]}'
        monthly_data[change_col] = (monthly_data[search_columns[i]] - monthly_data[search_columns[i-1]]) / monthly_data[search_columns[i-1]]
    
    # Get the change columns
    change_columns = [col for col in monthly_data.columns if col.startswith('mom_change_')]
    
    # Function to get top risers and fallers for a specific month
    def get_top_changes(month_col):
        month = month_col.replace('mom_change_searches_', '').replace('_', ' ')
        top_risers = monthly_data.nlargest(top_n, month_col)[['keyword', month_col]]
        top_fallers = monthly_data.nsmallest(top_n, month_col)[['keyword', month_col]]
        
        print(f"\nTop {top_n} Risers for {month}:")
        for _, row in top_risers.iterrows():
            print(f"{row['keyword']}: {row[month_col]:.2%}")
        
        print(f"\nTop {top_n} Fallers for {month}:")
# maxi wool dress: -50.00%
# cotton midi dress: -37.50%
# maxi sleeveless dress: -33.90%
#
# Top 5 Risers for feb 2024:
# resort wear evening dresses: inf%
# designer print dress: 300.00%
# maxi wool dress: 100.00%
# designer cotton dress: 66.67%
# long sleeve knitted dress: 46.15%
#
# Top 5 Fallers for feb 2024:
# designer sleeveless dress: -100.00%
# designer short sleeve dress: -66.67%
# beach cover ups: -45.45%
# designer knitted dresses: -44.44%
# designer summer dresses: -34.38%
#
# Top 5 Risers for mar 2024:
# designer short denim dress: inf%
# designer sleeveless dress: inf%
# designer knitted dresses: 240.00%
# maxi wool dress: 150.00%
# wool knitted dress: 142.86%
#
# Top 5 Fallers for mar 2024:
# summer party dresses: -56.41%
# designer print dress: -50.00%
# designer summer dresses: -47.62%
# designer linen dress: -47.06%
# designer cotton dress: -40.00%
#
# Top 5 Risers for apr 2024:
# wool knitted dress: 247.06%
# knit dresses: 125.00%
# long sleeve knitted dress: 125.00%
# wool midi dress: 125.00%
# maxi wool dress: 80.00%
#
# Top 5 Fallers for apr 2024:
# resort wear evening dresses: -100.00%
# designer print dress: -50.00%
# linen midi dress: -47.22%
# summer party dresses: -47.06%
# short sleeve midi dress: -37.50%

# %% [markdown]
# ### Closely spending

# %%
file_name_2 = 'Data | C.2.csv'
df2 = pd.read_csv(file_name_2,header=0)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1206 entries, 0 to 1205
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    1206 non-null   object
#  1   Spend    1206 non-null   object
#  2   Keyword  1206 non-null   object
# dtypes: object(3)
# memory usage: 28.4+ KB

# %%
#Convert Month column to datetime
df2['Month'] = pd.to_datetime(df2['Month'], format='%d/%m/%Y')

#Standardize Keyword column and lowercase it for consistency
df2['Keyword'] = df2['Keyword'].str.strip().str.lower()
df2 = df2.rename(columns={'Keyword': 'keyword'})

#Handle characters in Spend varaiable and convert it to float
df2['Spend'] = df2['Spend'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df2.head()
# Out:
#        Month    Spend                   keyword
# 0 2023-01-01  28903.0           beach cover ups
# 1 2023-01-01  14292.0    black cocktail dresses
# 2 2023-01-01   2131.0    black designer dresses
# 3 2023-01-01  22298.0  cocktail & formal styles
# 4 2023-01-01  24056.0          cocktail dresses

# %%
#Check for duplicates
df2[df2.duplicated(subset=['Month', 'keyword'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Month, Spend, keyword]
# Index: []

# %%
#Melt df to get months and search volumes in separate rows
search_columns = [col for col in df.columns if col.startswith("searches_")]
df_melted = df.melt(
    id_vars=['keyword', 'currency', 'avg_monthly_searches', 'three_month_change', 'yoy_change','competition', 'competition_indexed_value', 'top_of_page_bid_low_range', 'top_of_page_bid_high_range'],
    value_vars=search_columns,
    var_name='Month', 
    value_name='Search_Volume')

#Convert Month column to datetime
df_melted['Month'] = df_melted['Month'].str.replace('searches_', '', regex=False)
df_melted['Month'] = pd.to_datetime(df_melted['Month'], format='%b_%Y')

# %%
df_melted.head()
# Out:
#                   keyword currency  avg_monthly_searches  three_month_change  \
# 0         beach cover ups      AUD                6600.0               -0.19
# 1  black cocktail dresses      AUD                6600.0                0.00
# 2  black designer dresses      AUD                 260.0               -0.19
# 3        cocktail dresses      AUD               74000.0                0.00
# 4       cotton midi dress      AUD                 880.0               -0.41
#
#    yoy_change competition  competition_indexed_value  \
# 0        0.00        High                       98.0
# 1        0.00        High                      100.0
# 2       -0.19        High                       97.0
# 3        0.22        High                      100.0
# 4        0.23        High                      100.0
#
#    top_of_page_bid_low_range  top_of_page_bid_high_range      Month  \
# 0                       0.35                        1.69 2023-05-01
# 1                       0.41                        1.39 2023-05-01
# 2                       0.60                        1.83 2023-05-01
# 3                       0.39                        1.36 2023-05-01
# 4                       0.40                        1.86 2023-05-01
#
#    Search_Volume
# 0         4400.0
# 1         5400.0
# 2          320.0
# 3        60500.0
# 4          320.0

# %%
# Merging the dataframes on keyword and month
merged_df = df_melted.merge(df2, on=['keyword', 'Month'], how='inner')

# %%
merged_df.head()
# Out:
#                   keyword currency  avg_monthly_searches  three_month_change  \
# 0         beach cover ups      AUD                6600.0               -0.19
# 1  black cocktail dresses      AUD                6600.0                0.00
# 2  black designer dresses      AUD                 260.0               -0.19
# 3        cocktail dresses      AUD               74000.0                0.00
# 4       cotton midi dress      AUD                 880.0               -0.41
#
#    yoy_change competition  competition_indexed_value  \
# 0        0.00        High                       98.0
# 1        0.00        High                      100.0
# 2       -0.19        High                       97.0
# 3        0.22        High                      100.0
# 4        0.23        High                      100.0
#
#    top_of_page_bid_low_range  top_of_page_bid_high_range      Month  \
# 0                       0.35                        1.69 2023-05-01
# 1                       0.41                        1.39 2023-05-01
# 2                       0.60                        1.83 2023-05-01
# 3                       0.39                        1.36 2023-05-01
# 4                       0.40                        1.86 2023-05-01
#
#    Search_Volume    Spend
# 0         4400.0    733.0
# 1         5400.0   5596.0
# 2          320.0  21218.0
# 3        60500.0  15748.0
# 4          320.0  27689.0

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   keyword                     708 non-null    object
#  1   currency                    708 non-null    object
#  2   avg_monthly_searches        708 non-null    float64
#  3   three_month_change          708 non-null    float64
#  4   yoy_change                  708 non-null    float64
#  5   competition                 696 non-null    object
#  6   competition_indexed_value   696 non-null    float64
#  7   top_of_page_bid_low_range   600 non-null    float64
#  8   top_of_page_bid_high_range  600 non-null    float64
#  9   Month                       708 non-null    datetime64[ns]
#  10  Search_Volume               708 non-null    float64
#  11  Spend                       708 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(3)
# memory usage: 66.5+ KB

# %%
#Aggregating by month to get total spend and search volume for each month
agg_df = merged_df.groupby('Month').agg({'Spend': 'sum', 'Search_Volume': 'sum'}).reset_index()
agg_df.head()
# Out:
#        Month     Spend  Search_Volume
# 0 2023-05-01  962141.0       204010.0
# 1 2023-06-01  748864.0       192710.0
# 2 2023-07-01  881705.0       224480.0
# 3 2023-08-01  913441.0       252870.0
# 4 2023-09-01  943506.0       269460.0

# %%
months = agg_df['Month'].dt.strftime('%b-%Y') 
spend = agg_df['Spend']/1000  
search_volume = agg_df['Search_Volume']/1000 

fig, ax1 = plt.subplots(figsize=(10, 6))

#Using Bar chart for search volume and adding Spend line on top of that, with 2nd y-axis
ax1.bar(months, search_volume, color='green', alpha=0.6, label='Search Volume')

ax2 = ax1.twinx()
ax2.plot(months, spend, color='red', marker='o', label='Spend')

ax1.set_title('Monthly Spend and Search Volume')
ax1.set_xlabel('Month')
ax1.set_ylabel('Search Volume (K)', color='green')
ax2.set_ylabel('Spend ($)', color='red')

ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x)}K'))
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x)}K'))

ax1.grid(True)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
#Aggregating by keyword to get average spend and search volume for each keyword
agg2_df = merged_df.groupby(['keyword'], as_index=False).agg({'Search_Volume': 'mean','Spend': 'mean'})
agg2_df.head()
# Out:
#                   keyword  Search_Volume         Spend
# 0         beach cover ups    6858.333333  11673.166667
# 1  black cocktail dresses    6500.000000  17918.083333
# 2  black designer dresses     275.000000  14691.583333
# 3        cocktail dresses   78458.333333  16323.833333
# 4       cotton midi dress     936.666667  16302.500000

# %%
#Create a new Volume_to_Spend_Ratio column to measure the cost-performance of each keyword considering the volume
agg2_df['Volume_to_Spend_Ratio']=agg2_df['Search_Volume']/agg2_df['Spend']
agg2_df.head()
# Out:
#                   keyword  Search_Volume         Spend  Volume_to_Spend_Ratio
# 0         beach cover ups    6858.333333  11673.166667               0.587530
# 1  black cocktail dresses    6500.000000  17918.083333               0.362762
# 2  black designer dresses     275.000000  14691.583333               0.018718
# 3        cocktail dresses   78458.333333  16323.833333               4.806367
# 4       cotton midi dress     936.666667  16302.500000               0.057455

# %%
#Function to get top 4 and bottom 4 keywords based on Volume_to_Spend_Ratio 
def get_top_bottom_keywords(df):

    sorted_df = df.sort_values(by='Volume_to_Spend_Ratio', ascending=False)
    top_4_keywords = sorted_df.head(4)['keyword'].tolist()
    bottom_4_keywords = sorted_df.tail(4)['keyword'].tolist()

    return top_4_keywords, bottom_4_keywords

top_4, bottom_4 = get_top_bottom_keywords(agg2_df)
print("Top 4 Keywords:", top_4)
print("Bottom 4 Keywords:", bottom_4)
# Out:
# Top 4 Keywords: ['cocktail dresses', 'denim dresses', 'evening dresses', 'party dresses']
# Bottom 4 Keywords: ['designer sleeveless dress', 'designer casual dresses for daywear', 'resort wear evening dresses', 'designer short denim dress']

# %%
import matplotlib.pyplot as plt

def plot_bottom_keywords_subplot(df, bottom_4_keywords):
    # Create a figure and a 2x2 grid of subplots
    fig, axes = plt.subplots(2, 2, figsize=(14, 12))
    axes = axes.flatten()  # Flatten the axes array to easily index it

    for i, keyword in enumerate(bottom_4_keywords):
        # Filter the data for the current keyword
        keyword_data = df[df['keyword'] == keyword]
        
        # Extract the month, search volume, and spend data
        months = keyword_data['Month'].dt.strftime('%Y-%m')
        search_volume = keyword_data['Search_Volume']
        spend = keyword_data['Spend']

        # Bar chart for Search Volume on the left y-axis
        axes[i].bar(months, search_volume, color='green', alpha=0.6, label='Search Volume')

        # Line graph for Spend on the right y-axis
        ax2 = axes[i].twinx()
        ax2.plot(months, spend, color='blue', marker='o', label='Spend')

        # Titles and labels
        axes[i].set_title(f'Keyword: {keyword}')
        axes[i].set_xlabel('Month')
        axes[i].set_ylabel('Search Volume', color='green')
        ax2.set_ylabel('Spend', color='blue')

        # Add grid and legends
        axes[i].grid(True)
        axes[i].legend(loc='upper left')
        ax2.legend(loc='upper right')

        # Rotate x-ticks for better readability
        axes[i].set_xticklabels(months, rotation=45, ha='right')

    # Adjust layout
    plt.tight_layout()
    plt.show()

# Example usage with the bottom_4 keywords from the previous function
plot_bottom_keywords_subplot(merged_df, bottom_4)
