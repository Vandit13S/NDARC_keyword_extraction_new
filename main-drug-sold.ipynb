# %%
import pandas as pd
import json
from pydantic import BaseModel, Field, ValidationError, field_validator
from typing import List, Dict, Any
import ast

from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_community.llms import Ollama

# %%
listings = pd.read_parquet('data/L1L2_mixed_2024Feb-2024May_Incognito.parquet')
#listings.head()
unique_listings=pd.DataFrame(listings['drug_title'].unique(),columns=['listing'])

# %%
def dataframe_batches(df, batch_size=5):
    column_name = df.columns[0]
    total_rows = len(df)
    results = []

    for start in range(0, total_rows, batch_size):
        end = min(start + batch_size, total_rows)
        batch = df.iloc[start:end]
        
        batch_result = {str(element): [] for element in batch[column_name]}
        results.append(batch_result)

    return results

class ResponseChecks(BaseModel):
    data: Dict[str, List[Any]]
    
    @field_validator("data")
    def check_dict_format(cls, value):
        assert isinstance(value, dict), "Response must be a dictionary"
        assert len(value) > 0, "Dictionary must not be empty"
        for key, val in value.items():
            assert isinstance(val, list), f"Value for key '{key}' must be a list"
        return value

def execute_keyword_LLM(list_of_dicts, chain):
    results = []
    error_listings = []
    total_items = len(list_of_dicts)
    
    for index, item in enumerate(list_of_dicts, 1):
        # Display progress every 10 runs
        if index % 10 == 0 or index == total_items:
            print(f"Progress: {index}/{total_items} items processed")
        
        try:
            response = chain.run(test_data=item)
            output = ast.literal_eval(response)
            
            # Validate the output
            ResponseChecks(data=output)
            
            # If validation passes, add to results
            for key, value in output.items():
                results.append({"key": key, "value": value})
        
        except Exception as e:
            print(f"Error processing item {index}: {str(e)}")
            error_listings.append(item)
            continue
    
    # Create DataFrame from results
    df = pd.DataFrame(results)
    
    # Print summary
    print(f"\nProcessing complete.")
    print(f"Total items: {total_items}")
    print(f"Successful: {len(list_of_dicts) - len(error_listings)}")
    print(f"Errors: {len(error_listings)}")
    
    return df, error_listings

# %%
#Break the data frame into batches and convert it to dict for processing
list_of_dicts=dataframe_batches(unique_listings)

# %%
list_of_dicts = list_of_dicts[:40]

# %%
# Define the input and output formats
input_format = r"""{{
  'listing text here': [],
  'listing text here': [],
  ...
}}"""

output_format = r"""{{
  'listing text here': ['Main drug sold'],
  'listing text here': ['Main drug sold'],
  ...
}}"""

example_input = r"""{{
  'Selling A which is like B': [],
  '50x drug A having effects similar to B': [],
  'Selling A, B, C etc.': []
}}"""

example_output = r"""{{
  'Selling A which is like B': [A],
  '50x drug A having effects similar to B': [A],
  'Selling A, B, C etc.': []
}}"""

# Define the template for the prompt
template = f"""You are an expert and your task is to identify just the main drug sold from the given listing. There might be listings which compare a drug to another to explain the effects, but your job is to identify just the main drug sold. If there are multiple main drugs being sold, just keep the response empty. Follow the following Input/Output format, and an example is given for your understanding. Maximum of only 1 item can be the output for a given listing.

Input format:
{input_format}

Output format:
{output_format}

Example

Input:
{example_input}

Output:
{example_output}

Now perform the task on the following and strictly follow the output format and task instructions given above. Just return the output in the given format without any pre or post explanation or message. Make sure to identify the main drug sold, not the analogues or similar.:

{{test_data}}
"""

# %%
# Define the input and output formats
input_format = r"""{{
  'listing text here': [],
  'listing text here': [],
  ...
}}"""

output_format = r"""{{
  'listing text here': ['Main drug sold'],
  'listing text here': ['Main drug sold'],
  ...
}}"""


# Define the template for the prompt
template = f"""Identify the main drug sold in each listing. There can be either 0 or 1 main drug sold. If there are more than 1 or if you are unsure, just give empty response.

Input format:
{input_format}

Output format:
{output_format}

Now perform the task on the following and strictly follow the output format and task instructions given above. Just return the output in the given format without any pre or post explanation or message. Make sure to identify the main drug sold, not the analogues or similar.:

{{test_data}}
"""

# %%
# Create a PromptTemplate instance
prompt = PromptTemplate(template=template, input_variables=["test_data"])

# Initialize the Ollama LLM with the correct model name
#llm = Ollama(model="llama-3.1-8b-grimjim:latest")
llm = Ollama(model="llama-3.1-8-grimjim-Q8:latest") 

# Create the LLMChain
chain = LLMChain(llm=llm, prompt=prompt)

# Run the chain with the first element of list_of_dicts
'''response = chain.run(test_data=list_of_dicts[0])
try:
    output=ast.literal_eval(response)
except:
    output=''
    print('Invalid Response')
print(response)'''
# Out:
# /var/folders/hj/9q6mhx694j320ys__q4d5k8r0000gn/T/ipykernel_41064/1408986649.py:9: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)
# "response = chain.run(test_data=list_of_dicts[0])\ntry:\n    output=ast.literal_eval(response)\nexcept:\n    output=''\n    print('Invalid Response')\nprint(response)"

# %%
result_df, errors_df = execute_keyword_LLM(list_of_dicts, chain)
# Out:
# /var/folders/hj/9q6mhx694j320ys__q4d5k8r0000gn/T/ipykernel_41064/797077832.py:37: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   response = chain.run(test_data=item)
# Progress: 10/40 items processed
# Progress: 20/40 items processed
# Progress: 30/40 items processed
# Progress: 40/40 items processed
#
# Processing complete.
# Total items: 40
# Successful: 40
# Errors: 0

# %%
result_df.head(60)
# Out:
#                                                   key                 value
# 0            x50 Percocet 10mg Pharma Grade Fent Free            [Percocet]
# 1   Pre-loaded vape pen with Insanely Perfect Hear...           [Ayahuasca]
# 2   100mg Metta NMT, a beautiful vapable MDMA repl...               [Metta]
# 3   Peyote mescaline microdose Liquid Vial 5g in 5...    [Peyote mescaline]
# 4   1KG-EUTYLONE (KU) CYSTALS Analogue of MDMA (Sh...                    []
# 5                                 DMT + NMT vape cart                 [DMT]
# 6                                  DMT + NMT fumarate                 [DMT]
# 7                                  DMT + NMT freebase                 [DMT]
# 8            ACACIA Changa Pre-rolls (DMT, NMT, MAOI)                 [DMT]
# 9                                NMT + DMT vape juice                 [DMT]
# 10  RIPPED STACK Trenbolone Masterone testosterone...        [Testosterone]
# 11  50 x Xanax gg249 3mg bars Bromazolam US-US (50...          [Alprazolam]
# 12          HGH Human Growth Hormone 45IU Norditropin          [Somatropin]
# 13                     ACACIA changa (DMT, NMT, MAOI)                    []
# 14               ACACIA Pharmahuasca (DMT, NMT, MAOI)                    []
# 15  10ML MUSHROOM DROPS!! Synthetic Shrooms 4-AcO-...           [4-AcO-DMT]
# 16                          HGH Omnitrope 72IU (24mg)          [Somatropin]
# 17                                   Brown Sugar MDMA                [MDMA]
# 18      Valaciclovir 500 mg VALTREX tablet x 90 pills        [Valaciclovir]
# 19  Valaciclovir 1 gm(1000 mg) VALTREX tablet x 90...        [Valaciclovir]
# 20  Amitriptyline 12.5+Chlordiazepoxide 5 mg LIMBI...       [Amitriptyline]
# 21  LSD Drug Testing Kit (+1 Fent Test Strip and +...                 [LSD]
# 22  MDMA Drug Testing Kit (+1 Fent Test Strip and ...                [MDMA]
# 23  Psilocybin Drug Testing Kit (+1 Fent Test Stri...          [Psilocybin]
# 24  Cocaine Drug Testing Kit (+2 Fent Test Strips ...             [Cocaine]
# 25  DMT Drug Testing Kit (+1 Fent Test Strip and +...                 [DMT]
# 26  Amphetamine (Adderall) Drug Testing Kit (+1 Fe...         [Amphetamine]
# 27  50x M523 10mg Percocet Oxycodone| Pharma Grade...            [Percocet]
# 28    PROMO 1.2 ANY STRAIN 2 X XANAX 1 X DIAZEPAM X 1               [XANAX]
# 29                               DMT Vape Pen - 0.5ml                 [DMT]
# 30                                 DMT Vape Pen - 1ml                 [DMT]
# 31     x200 Oxycodone 30mg M30 Fent Free Pharma Grade           [Oxycodone]
# 32          25 Xanax X2 Bars 4mg NO FENT USA Domestic  [Alprazolam (Xanax)]
# 33  Tranxene Clorazepate Dipotassium 20mg x10 Sano...         [Clorazepate]
# 34  Wockhardt 16oz Pint 473ml Promethazine with Co...             [Codeine]
# 35  Polka Dot Mushroom Chocolate Bars  $18 Per - B...          [Psilocybin]
# 36  ☆Wizard's Staff ☆ 5-MeO-DMT Vape Cart ☆ Most P...           [5-MeO-DMT]
# 37  FREE EXPRESS - EXTRA UNIT SALE ADDERALL V3.3al...            [Adderall]
# 38  Paracetamol & Codeine – 16 tb/530 mg – Abiogen...             [Codeine]
# 39         pink 10mg Oxy fent free 100 pills USA ONLY           [Oxycodone]
# 40  50x Oxycodone M30 NON Fentanyl pills| Pharma G...           [Oxycodone]
# 41  Ketamine Drug Testing Kit (+2 Fent Test Strips...                    []
# 42  Pure fishscale cocaine AK47 Batch 92% pure TOP...             [Cocaine]
# 43  10 G Heroin | Fent Free | No Bullshit only the...              [Heroin]
# 44                Methylenedioxy-Methamphetamine MDMA                [MDMA]
# 45  Diazepam prodes 10mg and Rivotril pills usa to...            [Diazepam]
# 46  Best Quality Diazepam prodes 10mg and Rivotril...            [Diazepam]
# 47  High Quality Diazepam 10mg and Rivotril pills ...            [Diazepam]
# 48  Grade AA ++ Diazepam 10mg and Rivotril pills U...            [Diazepam]
# 49  1 bottle of codeine lean | 60mg Morphine | 100...                    []
# 50       Promethazine + Codeine Phosphate Syrup 100ml             [Codeine]
# 51  CODAMOL, 30mg Codeine and 500mg Paracetamol pe...             [Codeine]
# 52  GENOTROPIN QUICKPEN *hgh* 12mg (36 i.u.), Pfiz...                 [HGH]
# 53  14g new 4-MMC (Dipentylone crystal) SHIPPING A...                    []
# 54  7g new 4-MMC 4mmc Dipentylone(MDMA IMITATION) ...                    []
# 55  7g new 4-MMC 4MMC Dipentylone SHIPPING USA-USA...               [4-MMC]
# 56  Black Tar Heroin Fent Free 1 Gram BTH FF - IN ...              [Heroin]
# 57                       Tuci-Tucibi-2CB-Pink cocaine             [Cocaine]
# 58                                    3MMC MEPHEDRONE          [Mephedrone]
# 59  4mg Xanax v2090 (x20 with bulk pricing availab...          [Alprazolam]

# %%
result_df.iloc[21]['key']
# Out:
# 'LSD Drug Testing Kit (+1 Fent Test Strip and +1 Testing Tray)'

# %%
list_of_dicts
# Out:
# [{'x50 Percocet 10mg Pharma Grade Fent Free': [],
#   'Pre-loaded vape pen with Insanely Perfect Heart-openning Chakra smokable ayahuasca': [],
#   '100mg Metta NMT, a beautiful vapable MDMA replacement. Heart Chakra opens for 1hr meditation.': [],
#   'Peyote mescaline microdose Liquid Vial 5g in 5mL, 75 drops. Buk Discounts': [],
#   '1KG-EUTYLONE (KU) CYSTALS Analogue of MDMA (Shipping USA to USA)': []},
#  {'DMT + NMT vape cart': [],
#   'DMT + NMT fumarate': [],
#   'DMT + NMT freebase': [],
#   'ACACIA Changa Pre-rolls (DMT, NMT, MAOI)': [],
#   'NMT + DMT vape juice': []},
#  {'RIPPED STACK Trenbolone Masterone testosterone 300mg/ml 10ml - Liniment Pharma': [],
#   '50 x Xanax gg249 3mg bars Bromazolam US-US (50 Pills, 100 Pills and 200 Pills)': [],
#   'HGH Human Growth Hormone 45IU Norditropin': [],
#   'ACACIA changa (DMT, NMT, MAOI)': [],
#   'ACACIA Pharmahuasca (DMT, NMT, MAOI)': []},
#  {'10ML MUSHROOM DROPS!! Synthetic Shrooms 4-AcO-DMT UK': [],
#   'HGH Omnitrope 72IU (24mg)': [],
#   'Brown Sugar MDMA': [],
#   'Valaciclovir 500 mg VALTREX tablet x 90 pills': [],
#   'Valaciclovir 1 gm(1000 mg) VALTREX tablet x 90 pills': []},
#  {'Amitriptyline 12.5+Chlordiazepoxide 5 mg LIMBITROL tablet x 100 pills': [],
#   'LSD Drug Testing Kit (+1 Fent Test Strip and +1 Testing Tray)': [],
#   'MDMA Drug Testing Kit (+1 Fent Test Strip and +1 Testing Tray)': [],
#   'Psilocybin Drug Testing Kit (+1 Fent Test Strip and +1 Testing Tray)': [],
#   'Cocaine Drug Testing Kit (+2 Fent Test Strips and +1 Testing Tray)': []},
#  {'DMT Drug Testing Kit (+1 Fent Test Strip and +1 Testing Tray)': [],
#   'Amphetamine (Adderall) Drug Testing Kit (+1 Fent Test Strips and +1 Testing Tray)': [],
#   '50x M523 10mg Percocet Oxycodone| Pharma Grade Fent Free': [],
#   'PROMO 1.2 ANY STRAIN 2 X XANAX 1 X DIAZEPAM X 1': [],
#   'DMT Vape Pen - 0.5ml': []},
#  {'DMT Vape Pen - 1ml': [],
#   'x200 Oxycodone 30mg M30 Fent Free Pharma Grade': [],
#   '25 Xanax X2 Bars 4mg NO FENT USA Domestic': [],
#   'Tranxene Clorazepate Dipotassium 20mg x10 Sanofi Aventis': [],
#   'Wockhardt 16oz Pint 473ml Promethazine with Codeine Oral Solution - Quality Replica': []},
#  {'Polka Dot Mushroom Chocolate Bars  $18 Per - Bulk Rate': [],
#   "☆Wizard's Staff ☆ 5-MeO-DMT Vape Cart ☆ Most Potent in Universe ☆ Jaguar DMT 5meodmt 5meo": [],
#   'FREE EXPRESS - EXTRA UNIT SALE ADDERALL V3.3alpha PHARMAGRADE 30mg IR RACEMIC SALT L-AMPHETAMINE': [],
#   'Paracetamol & Codeine – 16 tb/530 mg – Abiogen – exp. 2027 (shipped from Spain)': [],
#   'pink 10mg Oxy fent free 100 pills USA ONLY': []},
#  {'50x Oxycodone M30 NON Fentanyl pills| Pharma Grade': [],
#   'Ketamine Drug Testing Kit (+2 Fent Test Strips and +1 Testing Tray)': [],
#   'Pure fishscale cocaine AK47 Batch 92% pure TOP - NEW BATCH': [],
#   '10 G Heroin | Fent Free | No Bullshit only the best!': [],
#   'Methylenedioxy-Methamphetamine MDMA': []},
#  {'Diazepam prodes 10mg and Rivotril pills usa to usa': [],
#   'Best Quality Diazepam prodes 10mg and Rivotril pills': [],
#   'High Quality Diazepam 10mg and Rivotril pills uk to uk': [],
#   'Grade AA ++ Diazepam 10mg and Rivotril pills USA USA': [],
#   '1 bottle of codeine lean | 60mg Morphine | 100ml | Self-brewed': []},
#  {'Promethazine + Codeine Phosphate Syrup 100ml': [],
#   'CODAMOL, 30mg Codeine and 500mg Paracetamol per Tablet, 16 Tablets.': [],
#   'GENOTROPIN QUICKPEN *hgh* 12mg (36 i.u.), Pfizer, Belgium': [],
#   '14g new 4-MMC (Dipentylone crystal) SHIPPING AUS-AUS ONLY': [],
#   '7g new 4-MMC 4mmc Dipentylone(MDMA IMITATION) AUS-AUS SHIPPING ONLY': []},
#  {'7g new 4-MMC 4MMC Dipentylone SHIPPING USA-USA ONLY': [],
#   'Black Tar Heroin Fent Free 1 Gram BTH FF - IN STOCK': [],
#   'Tuci-Tucibi-2CB-Pink cocaine': [],
#   '3MMC MEPHEDRONE': [],
#   '4mg Xanax v2090 (x20 with bulk pricing available) Bromazolam pressed bars Same Day Ship (FE)': []},
#  {'Promethazine + Codeine Solution 100ml': [],
#   '5-MeO-DMT Freebase ☆ Pure ☆ God molecule ☆ Bufo 5meo 5meodmt toad DMT': [],
#   'HGH Human Growth Hormone (Somatropin) 100 iu vial': [],
#   'Promethazine + Codeine Solution 100ml x 3 bottles': [],
#   'royale 450mg (generic soma + nucynta) 50 tablets': []},
#  {'royale 225mg (generic soma + nucynta) 50 tablets': [],
#   'Isotonitazene press oxycodone A215 30s': [],
#   '30s A215  Isotonitazene Oxycodone presses': [],
#   'Nebido (testosterone undecanoate) – 250mg/ml/ 4ml – Bayer – expires 01/2027 (shipped from Spain)': [],
#   '1KG-EUTYLONE (KU) CRYSTALS Analogue of MDMA (Shipping from CHINA)': []},
#  {'50-300 DEXEDRINE 10mg capsules spansules slow release pills dex dexys amphetamine a.d.d ADHD': [],
#   'Tapentadol and Carisoprodol – 10 tb/225 mg – exp. 02/2025 (shipped from Spain)': [],
#   '3-MMC Mephedrone Original': [],
#   'Codemol-30 x100 codeine phosphate and ': [],
#   'PROMETHAZINE WITH CODEINE ORAL SOLUTION (100 ML) SHIPPING US TO US ONLY': []},
#  {'| 5g-25g Bromazolam Powder Alprazolam "xanax" analogue | #USA-USA or AUS-AUS SHIPPING ONLY#': [],
#   '| 5g-112g Protonitazene Powder (Pressed "ROXY"M30 Powder) | #USA-USA or AUS-AUS SHIPPING ONLY#': [],
#   'Phentermine 30mg 5-HTP 100mg 60 Capsules Compounding capsules . Best Weight loss Formula in WORLD': [],
#   'codapine Forte Codeine phosphate30mg+Paracetamol 500mg 40 Tablets Two Boxes Blister seal': [],
#   'Phentermine 40mg 5-HTP 100mg 60 Capsules Compounding capsules . Best Weight loss Formula IN WORLD': []},
#  {'Dexedrine 5mg (min order size 100 pills) Dex Dexies Studdy Buddy Buddies 5s Speed': [],
#   'Testosterone Undecanoate / Andriol 250mg/ml 10x1ml Driada Medical': [],
#   'DNP ( 2,4-dinitrophenol ) + T3 100mg 50 capsule': [],
#   '▲ BENZOCAINE ▲ Cut you Cocaine with the best filler ▲ NEW VENDOR PROMO ▲ Nonsensia': [],
#   'Psilocybin Mushrooms Powder (99%)! (4-HO-MET)': []},
#  {'COLOMBIAN TUCIBI AKA PINK COCAINE/2CB': [],
#   'b 974 (Amphetamine and Dextroamphetamine 30 mg.)': [],
#   'b 973 (Amphetamine and Dextroamphetamine 20 mg.)': [],
#   'Testosterone Undecanoate / Andriol 250mg/ml 10ml Hilma Biocare': [],
#   '25 x dexedrine 10mg + 25 x dilaudid 8mg': []},
#  {'LUCY (TUSI) TUSI/TUSSI/TUCIBI/2C/2C-B/PINK COCAINE': [],
#   'AD30s Adderall 30mg pressed with meth zero fent.': [],
#   '- 100pills oxycodone 30mg - usa/usa - zero fent': [],
#   '10000 Xanax X2 Bars 4mg NO FENT USA Domestic': [],
#   '- 50x oxycodone 30mg - Fent free - free shipping !!!': []},
#  {'14 grams Black Mamba AAA Indoor! Overstock Fire Sale!': [],
#   '10 PACKS ♥COKE COLA ♥ CANNABIS EDIBLES THC 500mg ♥ UK': [],
#   '1 Ounce Black Mamba AAA Indoor! Overstock Fire Sale!': [],
#   'Party Pack |    1G K  |    1  G Hash |  1G Speed |    UK-UK': [],
#   'Buy 30mg T189 Oxycodone Fent Free (us to us)': []}]

# %%
import os

output_folder = 'output/Main drug'
file_name = 'llama3-1_q8_batchsize_5.csv'
file_path = os.path.join(output_folder, file_name)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

if os.path.exists(file_path):
    result_df.to_csv(file_path, mode='a', header=False, index=False)
else:
    result_df.to_csv(file_path, index=False)
