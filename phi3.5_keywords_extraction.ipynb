# %%
import pandas as pd
import json
import re
from pydantic import BaseModel, Field, ValidationError, field_validator
from typing import List, Dict, Any
import ast

from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain_community.llms import Ollama
# Out:
# /Users/vanditsadaphale/Library/Caches/pypoetry/virtualenvs/llama-fine-tuning-rZexxVwI-py3.9/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
listings = pd.read_csv('data/data_uncategorised_Oct21_to_Jan22.csv')
#listings.head()
unique_listings=pd.DataFrame(listings['drug_title'].unique(),columns=['listing'])
# Out:
# /var/folders/_0/s_2t6l510c3bdxngny7zmfyc0000gn/T/ipykernel_1714/247093999.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   listings = pd.read_csv('data/data_uncategorised_Oct21_to_Jan22.csv')

# %%
def dataframe_batches(df, batch_size=10):
    column_name = df.columns[0]
    total_rows = len(df)
    results = []

    for start in range(0, total_rows, batch_size):
        end = min(start + batch_size, total_rows)
        batch = df.iloc[start:end]
        
        batch_result = {str(element): [] for element in batch[column_name]}
        results.append(batch_result)

    return results

class ResponseChecks(BaseModel):
    data: Dict[str, List[Any]]
    
    @field_validator("data")
    def check_dict_format(cls, value):
        assert isinstance(value, dict), "Response must be a dictionary"
        assert len(value) > 0, "Dictionary must not be empty"
        for key, val in value.items():
            assert isinstance(val, list), f"Value for key '{key}' must be a list"
        return value

def process_invalid_json_response(response_text):
    """
    Process an invalid JSON response that contains unwanted text before the JSON-like structure.
    """
    match = re.search(r'\{[\s\S]*\}', response_text)
    
    if match:
        json_like_str = match.group(0)
        json_str = json_like_str.replace("'", '"')
        
        try:
            data = json.loads(json_str)
            return data
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            return None
    else:
        print("No valid JSON-like structure found in the response.")
        return None

def execute_keyword_LLM(list_of_dicts, chain):
    results = []
    error_listings = []
    total_items = len(list_of_dicts)
    
    for index, item in enumerate(list_of_dicts, 1):
        if index % 10 == 0 or index == total_items:
            print(f"Progress: {index}/{total_items} items processed")
        
        try:
            response = chain.run(test_data=item)
            
            # First, try to process as a valid JSON response
            try:
                output = ast.literal_eval(response)
            except (ValueError, SyntaxError):
                # If ast.literal_eval fails, try processing as invalid JSON
                output = process_invalid_json_response(response)
                if output is None:
                    raise ValueError("Failed to process response as JSON")
            
            # Validate the output
            ResponseChecks(data=output)
            
            # If validation passes, add to results
            for key, value in output.items():
                results.append({"key": key, "value": value})
        
        except Exception as e:
            print(f"Error processing item {index}: {str(e)}")
            error_listings.append(item)
            continue
    
    # Create DataFrame from results
    df = pd.DataFrame(results)
    
    # Print summary
    print(f"\nProcessing complete.")
    print(f"Total items: {total_items}")
    print(f"Successful: {len(list_of_dicts) - len(error_listings)}")
    print(f"Errors: {len(error_listings)}")
    
    return df, error_listings

# %%
#Break the data frame into batches and convert it to dict for processing
list_of_dicts=dataframe_batches(unique_listings)

# %%
list_of_dicts = list_of_dicts[:20]

# %%
# Define the input and output formats
input_format = r"""{{
  'listing text': [],
  'listing text': [],
  ...
}}"""

output_format = r"""{{
  'listing text': ['keyword1', 'keyword2', ...],
  'listing text': ['keyword1', 'keyword2', ...],
  ...
}}"""

example_input = r"""{{
  '1 Blister Codein 50mg Codeinium': [],
  '65 sample - choose what u want, mix and match': [],
  'SPECIAL PROMO: 500x S903-4mg Hulk Bars': [],
  '7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': [],
  '3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': [],
  'Pure Cocaine 98% purity, 5 grams available': [],
  'Acid tabs, blotters, LSD, 25mg each': [],
  '50 grams Cannabis buds - premium quality': [],
  'Xanax bars, 10mg - pharma grade': [],
  'Variety of pills and powders, 100% satisfaction guaranteed': [],
  'BD N BSM TEST BUNDLE 1OZ -indoor only- A++': []
}}"""

example_output = r"""{{
  '1 Blister Codein 50mg Codeinium': ['Codein', 'Codeinium'],
  '65 sample - choose what u want, mix and match': ['NA'],
  'SPECIAL PROMO: 500x S903-4mg Hulk Bars': ['S903', 'Hulk Bars'],
  '7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': ['LSD'],
  '3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': ['green crack'],
  'Pure Cocaine 98% purity, 5 grams available': ['Cocaine'],
  'Acid tabs, blotters, LSD, 25mg each': ['Acid', 'LSD'],
  '50 grams Cannabis buds - premium quality': ['Cannabis'],
  'Xanax bars, 10mg - pharma grade': ['Xanax'],
  'Variety of pills and powders, 100% satisfaction guaranteed': ['NA'],
  'BD N BSM TEST BUNDLE 1OZ -indoor only- A++': ['BD', 'BSM']
}}"""

# Define the template for the prompt
template = f"""Act as an NLP specialist, and your task is to extract keywords from the given substance listings scraped from the dark web. Keywords can include the main item of the listing, and/or any chemical name or compound mentioned, and/or any slang term related to illicit substances. General or common words in the listings like ‘ounces,’ ‘variety,’ ‘after,’ etc., are not considered keywords unless they are part of a recognized slang term. There could be more than 1 keyword in a given listing. 

Input format:
{input_format}

Output format:
{output_format}

Example

Input:
{example_input}

Output:
{example_output}

Now perform the task on the following listings and strictly follow the output format and task instructions given above. Remember there can be more than one keywords as well for a given listing. Please don't hallucinate and don't extract imaginary keywords. Listings data:

{{test_data}}
"""

# %%
#Llama 3 prompt
# Define the input and output formats
input_format = r"""{{
  'listing text': [],
  'listing text': [],
  ...
}}"""

output_format = r"""{{
  'listing text': ['keyword1', 'keyword2', ...],
  'listing text': ['keyword1', 'keyword2', ...],
  ...
}}"""

example_input = r"""{{
  '1 Blister Codein 50mg Codeinium': [],
  '65 sample - choose what u want, mix and match': [],
  'SPECIAL PROMO: 500x S903-4mg Hulk Bars': [],
  '7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': [],
  '3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': [],
  'Pure Cocaine 98% purity, 5 grams available': [],
  'Acid tabs, blotters, LSD, 25mg each': [],
  '50 grams Cannabis buds - premium quality': [],
  'Xanax bars, 10mg - pharma grade': [],
  'Variety of pills and powders, 100% satisfaction guaranteed': [],
  'BD N BSM TEST BUNDLE 1OZ -indoor only- A++': []
}}"""

example_output = r"""{{
  '1 Blister Codein 50mg Codeinium': ['Codein', 'Codeinium'],
  '65 sample - choose what u want, mix and match': ['NA'],
  'SPECIAL PROMO: 500x S903-4mg Hulk Bars': ['S903', 'Hulk Bars'],
  '7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': ['LSD'],
  '3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! NDD-FREE POSTAGE': ['green crack'],
  'Pure Cocaine 98% purity, 5 grams available': ['Cocaine'],
  'Acid tabs, blotters, LSD, 25mg each': ['Acid', 'LSD'],
  '50 grams Cannabis buds - premium quality': ['Cannabis'],
  'Xanax bars, 10mg - pharma grade': ['Xanax'],
  'Variety of pills and powders, 100% satisfaction guaranteed': ['NA'],
  'BD N BSM TEST BUNDLE 1OZ -indoor only- A++': ['BD', 'BSM']
}}"""

# Define the template for the prompt
template = f"""Extract keywords from the given substance listings scraped from the dark web. Keywords can include the main item of the listing, and/or any chemical name or compound mentioned, and/or any slang term related to illicit substances. General or common words in the listings like ‘ounces,’ ‘variety,’ ‘after,’ etc., are not considered keywords unless they are part of a recognized slang term.  

Input format:
{input_format}

Output format:
{output_format}

Example

Input:
{example_input}

Output:
{example_output}

Now perform the task on the following listings and strictly follow the output format and task instructions given above. Please don't hallucinate and don't extract imaginary keywords. Listings data:

{{test_data}}
"""

# %%
# Create a PromptTemplate instance
prompt = PromptTemplate(template=template, input_variables=["test_data"])

# Initialize the Ollama LLM with the correct model name
llm = Ollama(model="dolphin-llama3")

# Create the LLMChain
chain = LLMChain(llm=llm, prompt=prompt)

# Run the chain with the first element of list_of_dicts
#response = chain.run(test_data=list_of_dicts[1])
#try:
#    output=ast.literal_eval(response)
#except:
#    output=''
#    print('Invalid Response')
#print(response)

# %%
from datetime import datetime
tstart = datetime.now()
result_df, errors_df = execute_keyword_LLM(list_of_dicts, chain)
print (datetime.now()-tstart)
# Out:
# Progress: 10/20 items processed
# Error processing item 14: 1 validation error for ResponseChecks
# data
#   Input should be a valid dictionary [type=dict_type, input_value=({'3.5-56g Incredible Bul...['ENEMY OF THE STATE']}), input_type=tuple]
#     For further information visit https://errors.pydantic.dev/2.8/v/dict_type
# Error decoding JSON: Expecting ':' delimiter: line 6 column 92 (char 418)
# Error processing item 19: Failed to process response as JSON
# Progress: 20/20 items processed
#
# Processing complete.
# Total items: 20
# Successful: 18
# Errors: 2
# 0:01:30.067192

# %%
result_df.head(60)
# Out:
#                                                   key  \
# 0                     1 Blister Codein 50mg Codeinium
# 1       65 sample - choose what u want, mix and match
# 2              SPECIAL PROMO: 500x S903-4mg Hulk Bars
# 3                                   50 B707 BLUE BARS
# 4                                     TERCIAN 30x25mg
# 5                                     TERCIAN 10x25mg
# 6   500 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 7   250 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 8   1000 Pack Green S903 2.5 - 3.5Mg Per Bar Extra...
# 9           Eszopiclone (2 mg tabs). Generics 20 tabs
# 10  200 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 11                                 100 B707 BLUE BARS
# 12                                     1000 B707 Bars
# 13                       5 gram of pure 2-FDCK Powder
# 14                                   Test bundle 1-5g
# 15  14G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE PO...
# 16  28G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE PO...
# 17  7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POS...
# 18  3.5G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE P...
# 19                    Create your 4 gram test bundle!
# 20                  SOUTH AFRICAN DAGGA PUCKS 7 GRAMS
# 21                                            AMNESIA
# 22                                  THC CARTS 510 2ML
# 23                                  THC CARTS 510 5ML
# 24                                     Cola cubez 1g.
# 25                                            GMO 1g.
# 26                 10 x 1g vape carts variety flavors
# 27                               Manali Cream 50% Off
# 28                                1oz. PlatinumOGKush
# 29  3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! ND...
# 30         BD N BSM TEST BUNDLE 1OZ -indoor only- A++
# 31                   aus2aus - GREEN CRACK 7G- ozbabe
# 32                    Create your 2 gram test bundle!
# 33                    Create your 5 gram test bundle!
# 34                   Create your 10 gram test bundle!
# 35                 10g happy new year mix pack 4x 2,5
# 36                 aus2aus - EL PRESIDENTE 7G- ozbabe
# 37                                  1 oz Heartbreaker
# 38                           50 gr ENEMY OF THE STATE
# 39                   aus2aus - ICE WRECK 3.5G- ozbabe
# 40                                      10 gr CARMELO
# 41                                     250 gr CARMELO
# 42                                        14 g zookie
# 43                                       1 lb Pudding
# 44                   aus2aus - ICE WRECK 112G- ozbabe
# 45                aus2aus - EL PRESIDENTE 56G- ozbabe
# 46                            250g Star Dawg 1650 GBP
# 47   Lemongrass - Ounces - OZ - Major bulk discounts!
# 48              aus2aus - TROPIC TRUFFLE 112G- ozbabe
# 49                          1/4 lb Happily Ever After
# 50                                500 gr BRUCE BANNER
# 51                              7g Star Dawg 53.9 GBP
# 52                                  1 lb Heartbreaker
# 53                  aus2aus - GREEN CRACK 28G- ozbabe
# 54                    aus2ous - ICE WRECK 28G- ozbabe
# 55                     aus2ous - MARMALADE 7G- ozbabe
# 56                               3.5 to 28g Star Dawg
# 57                                100 gr BRUCE BANNER
# 58                                      50 gr CARMELO
# 59                    aus2aus - MARMALADE 56G- ozbabe
#
#                             value
# 0             [Codein, Codeinium]
# 1                            [NA]
# 2               [S903, Hulk Bars]
# 3               [B707, Blue Bars]
# 4                       [TERCIAN]
# 5                       [TERCIAN]
# 6              [S903, Green Bars]
# 7              [S903, Green Bars]
# 8              [S903, Green Bars]
# 9                   [Eszopticlon]
# 10             [S903, green bars]
# 11              [B707, BLUE BARS]
# 12                         [B707]
# 13                [2-FDCKEPOWDER]
# 14                             []
# 15                          [LSD]
# 16                          [LSD]
# 17                          [LSD]
# 18                          [LSD]
# 19                           [NA]
# 20                 [dagga, pucks]
# 21                      [amnesia]
# 22                   [THC, carts]
# 23                   [THC, carts]
# 24                    [cola cube]
# 25                          [gmo]
# 26  [vape carts, variety flavors]
# 27                           [NA]
# 28             [Platinum, OGKush]
# 29                  [green crack]
# 30                      [BD, BSM]
# 31          [Green Crack, ozbabe]
# 32                             []
# 33                             []
# 34                             []
# 35        [Ganja, happy new year]
# 36                 [EL President]
# 37                             []
# 38           [ENEMY of the State]
# 39          [ICE Wreck, o zebane]
# 40                      [Carmelo]
# 41                      [Carmelo]
# 42                        [Zooki]
# 43                             []
# 44          [ICE Wreck, o zebane]
# 45                 [EL President]
# 46                    [Star Dawg]
# 47               [Lemongrass, Oz]
# 48       [Tropic Truffle, ozbabe]
# 49           [Happily Ever After]
# 50                 [BRUCE BANNER]
# 51                [Star Dawg, NA]
# 52                 [Heartbreaker]
# 53          [Green Crack, ozbabe]
# 54            [Ice Wreck, ozbabe]
# 55            [Marmalade, ozbabe]
# 56                    [Star Dawg]
# 57                [BRUCE, BANNER]
# 58                      [CARMELO]
# 59                    [Marmalade]

# %%
result_df.tail(60)
# Out:
#                                                    key  \
# 114  Purple Panty Dropper - Ounces - OZ - Major bul...
# 115                                     100 gr CARMELO
# 116                                       1 oz Macmosa
# 117                          aus2aus - G13 28G- ozbabe
# 118                    aus2aus - ICE WRECK 14G- ozbabe
# 119                            500g Star Dawg 3250 GBP
# 120                aus2aus - EL PRESIDENTE 14G- ozbabe
# 121               Blue Satellite 224g Free Shipping!!!
# 122                            1/4 lb ICE CREAM SOCIAL
# 123                                     1/4 lb Macmosa
# 124                                     1/2 lb Macmosa
# 125                Blue Satellite 14g Free Shipping!!!
# 126                 aus2aus - GREEN CRACK 112G- ozbabe
# 127                        1G Moonrock / EUROPE and UK
# 128                        2G Moonrock / EUROPE and UK
# 129                          100 gr ENEMY OF THE STATE
# 130                                     3.5g moonrocks
# 131                          250 gr ENEMY OF THE STATE
# 132                          500 gr ENEMY OF THE STATE
# 133                         1000 gr ENEMY OF THE STATE
# 134                                        3 gr CHANEL
# 135                                     5 gr GELATO 41
# 136                                        5 gr CHANEL
# 137                                       10 gr CHANEL
# 138                                       25 gr CHANEL
# 139                                       50 gr CHANEL
# 140                                      100 gr CHANEL
# 141                                      250 gr CHANEL
# 142                         10 g - Silvergrape Sherbet
# 143             10 g - San Fernando Valley x The Purps
# 144                        (2 x 5g) Choose your strain
# 145            Friendly Farms ( 9 Dollars X 10 pieces)
# 146                        1oz. distillate(With Terps)
# 147                West Coast Cure Pen (9 X 10 pieces)
# 148          New Vendor Friendly Farms (9 X 10 pieces)
# 149                          Muha Med  (9 X 10 pieces)
# 150            Friendly Farms ( 9 Dollars X 15 pieces)
# 151                            3.5 grams THCA DIAMONDS
# 152                          Cali Plug (9 X 10 pieces)
# 153                               KRT  (9 X 10 pieces)
# 154                              Pure One 1G Cartrdige
# 155  3 grams - THCA Diamonds in HTFSE Terp Sauce - ...
# 156                           1ML Distillate CA Import
# 157                   5ml GSC Full Spectrum Distillate
# 158  1ML - 250ML RAW THC DISTILLATE | DISCOUNTS IN ...
# 159  3 grams - THCA Diamonds in HTFSE Terp Sauce - ...
# 160                       510 Threaded Stealth Battery
# 161                         Heavy Hitters 1G Cartridge
# 162  3 grams - THCA Diamonds in HTFSE Terp Sauce - ...
# 163                     10ml Strong 30% THC Vape juice
# 164                              500mg THC Carts 0.5ml
# 165                  10ml GSC Full Spectrum Distillate
# 166                     THC Diamonds (1G) (90%+) (USA)
# 167  5ml CannaJuice THC Vape Liquid - 200mg / ml (1...
# 168  SankaWIC UK. **THC VAPE STARTER BUNDLE** (510 ...
# 169                 1x 1g TKO Cart F Your Plug Special
# 170                         thc diamonds - 1g (8g max)
# 171  WEST COAST CURE PEN, 1g VAPE CARTS. 4 New Flav...
# 172                       Chocolate Trip Vape Cart 1ml
# 173                   THC Diamonds (3.5G) (90%+) (USA)
#
#                                           value
# 114                                     [Ounce]
# 115                             [CarmeLo, gram]
# 116                            [Macmosa, ounce]
# 117            [G13, ice wreck, ounces, ozbabe]
# 118          [Ice Wreck, grams, ounces, ozbabe]
# 119                    [Star Dawg, gram, pound]
# 120  [EL Presidente, ice wreck, ounces, ozbabe]
# 121                      [grams, free shipping]
# 122  [quarter pounder, pound, ice cream social]
# 123                  [Macmosa, quarter pounder]
# 124                                   [Macmosa]
# 125                                        [NA]
# 126                       [green crack, ozbabe]
# 127                                  [Moonrock]
# 128                                  [Moonrock]
# 129              [Egyptian Enemy, State Threat]
# 130                                 [moonrocks]
# 131                  [Enemy State, Grain Count]
# 132                [Estate Enemy, Threat Grain]
# 133                        [Mega Estate Threat]
# 134                                    [CHANEL]
# 135                                [GELATO, 41]
# 136                                    [CHANEL]
# 137                                    [CHANEL]
# 138                                    [CHANEL]
# 139                                    [CHANEL]
# 140                                    [CHANEL]
# 141                                    [CHANEL]
# 142                       [Silvergrape Sherbet]
# 143            [San Fernando Valley, The Purps]
# 144                                        [NA]
# 145                            [Friendly Farms]
# 146                      [distillate, terpenes]
# 147                       [West Coast Cure Pen]
# 148                            [Friendly Farms]
# 149                                  [Muha Med]
# 150                            [Friendly Farms]
# 151                             [THC, diamonds]
# 152                 [California plug, cannabis]
# 153                                          []
# 154                                 [Cartridge]
# 155                                        [NA]
# 156                      [Distillate, Cannabis]
# 157            [GSC, Full Spectrum, Distillate]
# 158                   [THC Distillate, RAW Thc]
# 159                                        [NA]
# 160                                   [Battery]
# 161                       [Cartridge, Cannabis]
# 162                                        [NA]
# 163                           [THC Juice, Vape]
# 164                                [THC, carts]
# 165                           [GSC, distillate]
# 166                              [THC diamonds]
# 167              [THC, cannaJuice, vape liquid]
# 168            [THC, vapouriser bundles, carts]
# 169                                  [TKO cart]
# 170                              [THC diamonds]
# 171             [Vape carts, West Coast curing]
# 172                 [Chocolate trip, vape cart]
# 173                              [THC diamonds]

# %%
result_df.head(60)
# Out:
#                                                   key  \
# 0                     1 Blister Codein 50mg Codeinium
# 1      65 sample  - choose what u want, mix and match
# 2              SPECIAL PROMO: 500x S903-4mg Hulk Bars
# 3                                   50 B707 BLUE BARS
# 4                                     TERCIAN 30x25mg
# 5                                     TERCIAN 10x25mg
# 6   500 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 7   250 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 8   1000 Pack Green S903 2.5 - 3.5Mg Per Bar Extra...
# 9   100 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 10          Eszopiclone (2 mg tabs). Generics 20 tabs
# 11  200 Pack Green S903 2.5 - 3.5Mg Per Bar Extras...
# 12                                 100 B707 BLUE BARS
# 13                                1000 B707 BLUE BARS
# 14                                       50 B707 Bars
# 15                       5 gram of pure 2-FDCK Powder
# 16                                   Test bundle 1-5g
# 17  14G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE PO...
# 18  28G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE PO...
# 19  7G L.S.D A+++ TOP PRICES IN UK!!! NDD-FREE POS...
# 20  3.5G L.SD A+++ TOP PRICES IN UK!!! NDD- FREE P...
# 21                    Create your 4 gram test bundle!
# 22                  SOUTH AFRICAN DAGGA PUCKS 7 GRAMS
# 23                                            AMNESIA
# 24                                  THC CARTS 510 2ML
# 25                                  THC CARTS 510 5ML
# 26                                     Cola cubez 1g.
# 27                                            GMO 1g.
# 28                 10 x 1g vape carts variety flavors
# 29                               Manali Cream 50% Off
# 30                                1oz. PlatinumOGKush
# 31                                     1oz. Moonrocks
# 32  3.5-56G GREEN CRACKA+++ TOP PRICES IN UK!!! ND...
# 33         BD N BSM TEST BUNDLE 1OZ -indoor only- A++
# 34                  BD and BSM test bundle for 5g-10g
# 35                   aus2aus - GREEN CRACK 7G- ozbabe
# 36                    Create your 2 gram test bundle!
# 37                    Create your 5 gram test bundle!
# 38                   Create your 10 gram test bundle!
# 39                 10g happy new year mix pack 4x 2,5
# 40                 aus2aus - EL PRESIDENTE 7G- ozbabe
# 41                                  1 oz Heartbreaker
# 42                           50 gr ENEMY OF THE STATE
# 43                   aus2aus - ICE WRECK 3.5G- ozbabe
# 44                                      10 gr CARMELO
# 45                                     250 gr CARMELO
# 46                                        14 g zookie
# 47                                       1 lb Pudding
# 48                   aus2aus - ICE WRECK 112G- ozbabe
# 49                aus2aus - EL PRESIDENTE 56G- ozbabe
# 50                            250g Star Dawg 1650 GBP
# 51  Lemongrass  - Ounces  - OZ  - Major bulk disco...
# 52             aus2aus  - TROPIC TRUFFLE 112G- ozbabe
# 53                          1/4 lb Happily Ever After
# 54                                500 gr BRUCE BANNER
# 55                              7g Star Dawg 53.9 GBP
# 56                                  1 lb Heartbreaker
# 57                 aus2aus  - GREEN CRACK 28G- ozbabe
# 58                   aus2aus  - ICE WRECK 28G- ozbabe
# 59                    aus2aus  - MARMALADE 7G- ozbabe
#
#                        value
# 0        [Codein, Codeinium]
# 1                       [NA]
# 2          [S903, Hulk Bars]
# 3          [B707, BLUE BARS]
# 4                  [Teracin]
# 5                  [Teracin]
# 6               [Green S903]
# 7               [Green S903]
# 8               [Green S903]
# 9               [Green S903]
# 10       [Eszopiclone, tabs]
# 11             [S903, green]
# 12         [B707, BLUE BARS]
# 13         [B707, BLUE BARS]
# 14              [B707, Bars]
# 15          [2-FDCK, Powder]
# 16            [Test, bundle]
# 17                     [LSD]
# 18                     [LSD]
# 19                     [LSD]
# 20                     [LSD]
# 21                      [NA]
# 22                   [Dagga]
# 23                 [Amnesia]
# 24              [THC, carts]
# 25              [THC, carts]
# 26              [Cola cubes]
# 27                     [GMO]
# 28             [vape, carts]
# 29                      [NA]
# 30        [Platinum OG Kush]
# 31               [Moonrocks]
# 32             [Green Crack]
# 33                 [BD, BSM]
# 34                 [BD, BSM]
# 35             [Green Crack]
# 36                      [NA]
# 37                      [NA]
# 38                      [NA]
# 39                      [NA]
# 40           [EL PRESIDENTE]
# 41            [Heartbreaker]
# 42      [ENEMY OF THE STATE]
# 43               [ICE WRECK]
# 44                 [CARMELO]
# 45                 [CARMELO]
# 46                  [zookie]
# 47                 [Pudding]
# 48               [ICE WRECK]
# 49           [EL PRESIDENTE]
# 50               [Star Dawg]
# 51  [Lemongrass, Ounces, OZ]
# 52          [Tropic Truffle]
# 53      [Happily Ever After]
# 54            [Bruce Banner]
# 55               [Star Dawg]
# 56            [Heartbreaker]
# 57             [Green Crack]
# 58               [Ice Wreck]
# 59               [Marmalade]

# %%
result_df.tail(60)
# Out:
#                                                    key  \
# 119                                        ChemDogg CD
# 120                   aus2aus - MARMALADE 3.5G- ozbabe
# 121                Blue Satellite 56g Free Shipping!!!
# 122                                 1/4 LB CHERRYWANNA
# 123                     aus2aus - ICE WRECK 7G- ozbabe
# 124                            14g Gelato 41 121.1 GBP
# 125               aus2aus - TROPIC TRUFFLE 14G- ozbabe
# 126                                        1g MOONROCK
# 127                            28g Green Crack 220 GBP
# 128                                       3 gr CARMELO
# 129  Purple Panty Dropper  - Ounces  - OZ  - Major ...
# 130                                     100 gr CARMELO
# 131                                       1 oz Macmosa
# 132                         aus2aus  - G13 28G- ozbabe
# 133                   aus2aus  - ICE WRECK 14G- ozbabe
# 134                            500g Star Dawg 3250 GBP
# 135               aus2aus  - EL PRESIDENTE 14G- ozbabe
# 136               Blue Satellite 224g Free Shipping!!!
# 137                            1/4 lb ICE CREAM SOCIAL
# 138                                     1/4 lb Macmosa
# 139                                     1/2 lb Macmosa
# 140                Blue Satellite 14g Free Shipping!!!
# 141                 aus2aus - GREEN CRACK 112G- ozbabe
# 142                        1G Moonrock / EUROPE and UK
# 143                        2G Moonrock / EUROPE and UK
# 144                          100 gr ENEMY OF THE STATE
# 145                                     3.5g moonrocks
# 146                          250 gr ENEMY OF THE STATE
# 147                          500 gr ENEMY OF THE STATE
# 148                         1000 gr ENEMY OF THE STATE
# 149                                        3 gr CHANEL
# 150                                     5 gr GELATO 41
# 151                                        5 gr CHANEL
# 152                                       10 gr CHANEL
# 153                                       25 gr CHANEL
# 154                                       50 gr CHANEL
# 155                                      100 gr CHANEL
# 156                                      250 gr CHANEL
# 157                        10 g  - Silvergrape Sherbet
# 158            10 g  - San Fernando Valley x The Purps
# 159                        (2 x 5g) Choose your strain
# 160             Friendly Farms ( 9 Dollars X 10 pices)
# 161                        1oz. distillate(With Terps)
# 162                 West Coast Cure Pen (9 X 10 pices)
# 163           New Vendor Friendly Farms (9 X 10 pices)
# 164                            Muha Med (9 X 10 pices)
# 165             Friendly Farms ( 9 Dollars X 15 pices)
# 166                            3.5 grams THCA DIAMONDS
# 167                           Cali Plug (9 X 10 pices)
# 168                                 KRT (9 X 10 pices)
# 169                              500mg THC Carts 0.5ml
# 170                  10ml GSC Full Spectrum Distillate
# 171                     THC Diamonds (1G) (90%+) (USA)
# 172  5ml CannaJuice THC Vape Liquid - 200mg / ml (1...
# 173  SankaWIC UK. **THC VAPE STARTER BUNDLE** (510 ...
# 174                 1x 1g TKO Cart F Your Plug Special
# 175                         thc diamonds - 1g (8g max)
# 176  WEST COAST CURE PEN, 1g VAPE CARTS. 4 New Flav...
# 177                       Chocolate Trip Vape Cart 1ml
# 178                   THC Diamonds (3.5G) (90%+) (USA)
#
#                                                  value
# 119                                         [ChemDogg]
# 120                                        [Marmalade]
# 121                                   [Blue Satellite]
# 122                                      [CherryWanna]
# 123                                        [Ice Wreck]
# 124                                       [Gelato, 41]
# 125                                   [Tropic Truffle]
# 126                                         [Moonrock]
# 127                                      [Green Crack]
# 128                                          [Carmelo]
# 129                 [Purple Panty Dropper, Ounces, OZ]
# 130                                          [CARMELO]
# 131                                          [Macmosa]
# 132                                              [G13]
# 133                                        [ICE WRECK]
# 134                                        [Star Dawg]
# 135                                    [EL PRESIDENTE]
# 136                                   [Blue Satellite]
# 137                                 [ICE CREAM SOCIAL]
# 138                                          [Macmosa]
# 139                                          [Macmosa]
# 140                                   [Blue Satellite]
# 141                              [Green Crack, ozbabe]
# 142                                         [Moonrock]
# 143                                         [Moonrock]
# 144                               [ENEMY OF THE STATE]
# 145                                        [moonrocks]
# 146                               [ENEMY OF THE STATE]
# 147                               [ENEMY OF THE STATE]
# 148                               [ENEMY OF THE STATE]
# 149                                           [CHANEL]
# 150                                           [GELATO]
# 151                                           [CHANEL]
# 152                                           [CHANEL]
# 153                                           [CHANEL]
# 154                                           [CHANEL]
# 155                                           [CHANEL]
# 156                                           [CHANEL]
# 157                              [Silvergrape Sherbet]
# 158                   [San Fernando Valley, The Purps]
# 159                                     [THC, strains]
# 160                    [Friendly Farms, dollar, pices]
# 161                                [distillate, terps]
# 162                      [West Coast Cure, pen, pices]
# 163        [New Vendor, Friendly Farms, dollar, pices]
# 164                                  [Muha Med, pices]
# 165                    [Friendly Farms, dollar, pices]
# 166                                   [THCA, DIAMONDS]
# 167                                 [Cali Plug, pices]
# 168                                       [KRT, pices]
# 169                                              [THC]
# 170                    [GSC, Full Spectrum Distillate]
# 171                                     [THC Diamonds]
# 172                      [CannaJuice, THC Vape Liquid]
# 173  [SankaWIC, 510 Thread Battery, Pre filled THC ...
# 174                                         [TKO Cart]
# 175                                     [THC Diamonds]
# 176                  [WEST COAST CURE PEN, VAPE CARTS]
# 177                        [Chocolate Trip, Vape Cart]
# 178                                     [THC Diamonds]

# %%
import os

output_folder = 'output'
file_name = 'gemma2_10.csv'
file_path = os.path.join(output_folder, file_name)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

if os.path.exists(file_path):
    result_df.to_csv(file_path, mode='a', header=False, index=False)
else:
    result_df.to_csv(file_path, index=False)

# %%
list_of_dicts=dataframe_batches(unique_listings)
list_of_dicts = list_of_dicts[501:1300]
result_df, errors_df = execute_keyword_LLM(list_of_dicts, chain)

import os

output_folder = 'output'
file_name = 'gemma2_10.csv'
file_path = os.path.join(output_folder, file_name)

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

if os.path.exists(file_path):
    result_df.to_csv(file_path, mode='a', header=False, index=False)
else:
    result_df.to_csv(file_path, index=False)
# Out:
# Progress: 10/799 items processed
# Progress: 20/799 items processed
# Progress: 30/799 items processed
# Progress: 40/799 items processed
# Progress: 50/799 items processed
# Progress: 60/799 items processed
# Progress: 70/799 items processed
# Progress: 80/799 items processed
# Progress: 90/799 items processed
# Progress: 100/799 items processed
# Progress: 110/799 items processed
# Progress: 120/799 items processed
# Progress: 130/799 items processed
# Progress: 140/799 items processed
# Progress: 150/799 items processed
# Progress: 160/799 items processed
# Progress: 170/799 items processed
# Progress: 180/799 items processed
# Progress: 190/799 items processed
# Progress: 200/799 items processed
# Progress: 210/799 items processed
# Progress: 220/799 items processed
# Progress: 230/799 items processed
# Progress: 240/799 items processed
# Progress: 250/799 items processed
# Progress: 260/799 items processed
# Progress: 270/799 items processed
# Progress: 280/799 items processed
# Progress: 290/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 11 column 21 (char 546)
# Error processing item 291: Failed to process response as JSON
# Progress: 300/799 items processed
# Progress: 310/799 items processed
# Progress: 320/799 items processed
# Progress: 330/799 items processed
# Progress: 340/799 items processed
# Progress: 350/799 items processed
# Progress: 360/799 items processed
# Progress: 370/799 items processed
# Progress: 380/799 items processed
# Progress: 390/799 items processed
# Progress: 400/799 items processed
# Progress: 410/799 items processed
# Progress: 420/799 items processed
# Progress: 430/799 items processed
# Progress: 440/799 items processed
# Progress: 450/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 3 column 51 (char 117)
# Error processing item 454: Failed to process response as JSON
# Progress: 460/799 items processed
# Progress: 470/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 3 column 5 (char 64)
# Error processing item 478: Failed to process response as JSON
# Progress: 480/799 items processed
# Progress: 490/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 10 column 18 (char 487)
# Error processing item 499: Failed to process response as JSON
# Progress: 500/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 5 column 37 (char 231)
# Error processing item 504: Failed to process response as JSON
# Progress: 510/799 items processed
# Progress: 520/799 items processed
# Progress: 530/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 6 column 24 (char 301)
# Error processing item 531: Failed to process response as JSON
# Progress: 540/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 2 column 21 (char 22)
# Error processing item 544: Failed to process response as JSON
# Progress: 550/799 items processed
# Progress: 560/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 6 column 31 (char 252)
# Error processing item 561: Failed to process response as JSON
# Error decoding JSON: Expecting ':' delimiter: line 11 column 14 (char 488)
# Error processing item 566: Failed to process response as JSON
# Progress: 570/799 items processed
# Progress: 580/799 items processed
# Progress: 590/799 items processed
# Progress: 600/799 items processed
# Progress: 610/799 items processed
# Progress: 620/799 items processed
# Progress: 630/799 items processed
# Progress: 640/799 items processed
# Progress: 650/799 items processed
# Progress: 660/799 items processed
# Progress: 670/799 items processed
# Progress: 680/799 items processed
# Progress: 690/799 items processed
# Progress: 700/799 items processed
# Progress: 710/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 4 column 23 (char 119)
# Error processing item 714: Failed to process response as JSON
# Progress: 720/799 items processed
# Progress: 730/799 items processed
# Progress: 740/799 items processed
# Progress: 750/799 items processed
# Progress: 760/799 items processed
# Progress: 770/799 items processed
# Error decoding JSON: Expecting ':' delimiter: line 3 column 23 (char 90)
# Error processing item 775: Failed to process response as JSON
# Progress: 780/799 items processed
# Progress: 790/799 items processed
# Progress: 799/799 items processed
#
# Processing complete.
# Total items: 799
# Successful: 788
# Errors: 11
